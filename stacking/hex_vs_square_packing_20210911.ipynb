# %% [markdown]
# # Objective
#
# Plot hexagonal packing efficiency vs. square packing efficiency.
#
# Color markers by:
# - amphora period
# - amphora region
# - amphora content
# - amphora volume
#
# # Observations
#
# - There are currently more jars (8 out of 13) where square packing is more efficient than hexagonal packing.
# - Of the 5 jars where hexagonal packing is more efficient, there are 3 jars where square and hexagonal packing are pretty much equally efficient.
# - There are currently no obvious clusters by period, content, volume, and region.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from mpl_toolkits.axes_grid1 import make_axes_locatable
import numpy as np

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv('Amphora Stacking 20210911.csv')

# %%
df
# Out:
#                 Status as of 9/9/21 according to J.V.  \
# 0                             Reg sq and reg hex done
# 1                             Reg sq and reg hex done
# 2                             Reg sq and reg hex done
# 3                             Reg sq and reg hex done
# 4   Reg sq and reg hex done, spaced rect and hex done
# 5                             Reg sq and reg hex done
# 6   Reg sq and reg hex done, spaced rect and hex done
# 7                             Reg sq and reg hex done
# 8                             Reg sq and reg hex done
# 9                             Reg sq and reg hex done
# 10                            Reg sq and reg hex done
# 11                            Reg sq and reg hex done
# 12                            Reg sq and reg hex done
#
#                  Amphora Type        Period   Region     Content  \
# 0          Africana 1 Piccolo        Middle  Central         Oil
# 1          Africana 2A Grande        Middle  Central        Wine
# 2                  Almagro 50  Middle, Late     West  Fish sauce
# 3               Almagro 51A-B  Middle, Late     West  Fish sauce
# 4                  Cretoise 1         Early     East        Wine
# 5                  Dressel 1A         Early  Central        Wine
# 6                  Dressel 20         Early     West         Oil
# 7                  Gauloise 4         Early     West        Wine
# 8                   Kapitan 2        Middle     East        Wine
# 9                Late Roman 1          Late     East   Oil, wine
# 10               Late Roman 2          Late     East   Oil, wine
# 11               Late Roman 3          Late     East        Wine
# 12  Mid-Roman 1 (/Agora M254)        Middle  Central        Wine
#
#    Model Creation (Initials & Date)         Model Check 1 (Initials & Date)  \
# 0                     C.W., 7/14/21                            S.C. 7/21/21
# 1                    U.P., 7/13/21                             C.W. 7/20/21
# 2                      U.P. 7/27/21                            J.V. 8/11/21
# 3                     U.P., 7/13/21                             J.V. 8/2/21
# 4                     U.P., 7/13/21                             J.V. 8/2/21
# 5                      S.C. 7/28/21  J.V. 8/27/21 (reg sq) 9/8/21 (reg hex)
# 6                              E.W.                           U.P., 7/18/21
# 7                      C.W. 7.20/21                            J.V. 8/13/21
# 8                     U.P., 7/13/21                            J.V. 8/11/21
# 9                     S.C., 7/13/21                           U.P., 7/15/21
# 10                      C.W. 8/2/21                            J.V. 9/11/21
# 11                     S.C. 7/26/21                            J.V. 8/27/21
# 12                    U.P., 7/13/21                            J.V. 8/13/21
#
#     Model Check 2 (Initials & Date)  Amphora Vol. [L]  Sq. Unit Width [m]  \
# 0                      J.V. 7/24/21         42.500000             0.29552
# 1                      J.V. 7/24/21         77.900000             0.44700
# 2                               NaN         18.870000             0.21400
# 3                               NaN         16.581294             0.23900
# 4                               NaN         22.775000             0.27600
# 5                               NaN         21.759870             0.28400
# 6   JV has a question, see comment.         76.151747             0.54100
# 7                               NaN         34.908062             0.41200
# 8                               NaN         12.629000             0.25900
# 9                      C.W. 7/20/21         24.359309             0.31300
# 10                              NaN         77.177000             0.53900
# 11                              NaN          4.444057             0.18100
# 12                              NaN         19.809250             0.32800
#
#     Sq. Unit Height [m]  Sq. Unit Volume [m^3]  Sq. Pack. Eff. (Auto)  \
# 0               1.76435               0.154084               0.551646
# 1               1.20000               0.239771               0.649787
# 2               1.58000               0.072358               0.521576
# 3               1.03500               0.059120               0.560935
# 4               0.98900               0.075338               0.604608
# 5               1.53200               0.123565               0.352201
# 6               0.84000               0.245852               0.619492
# 7               0.69600               0.118142               0.590952
# 8               0.79000               0.052994               0.476620
# 9               0.81300               0.079649               0.611668
# 10              0.81900               0.237937               0.648719
# 11              0.43800               0.014349               0.619410
# 12              0.55400               0.059602               0.664723
#
#     Hex. Unit Side Length [m]  Hex. Unit Height [m]  \
# 0                     0.29666               1.79343
# 1                     0.44700               1.42800
# 2                     0.21400               1.68200
# 3                     0.23900               1.18900
# 4                     0.27600               1.13800
# 5                     0.28400               1.72300
# 6                     0.54000               1.30000
# 7                     0.41200               1.01000
# 8                     0.25900               1.05500
# 9                     0.31300               1.02950
# 10                    0.53809               0.98388
# 11                    0.18100               0.63100
# 12                    0.32800               0.82700
#
#     Hex. Pack. Unit Volume [m^3]  Hex. Pack. Eff. (Auto)
# 0                       0.410067                0.621850
# 1                       0.741302                0.630512
# 2                       0.200127                0.565741
# 3                       0.176453                0.563820
# 4                       0.225223                0.606733
# 5                       0.361055                0.361604
# 6                       0.984879                0.463926
# 7                       0.445418                0.470229
# 8                       0.183867                0.412113
# 9                       0.262040                0.557762
# 10                      0.740123                0.625656
# 11                      0.053708                0.496469
# 12                      0.231156                0.514179

# %% [markdown]
# ## Plots

# %%
eff_sq = df['Sq. Pack. Eff. (Auto)']
eff_hx = df['Hex. Pack. Eff. (Auto)']

# %%
fs_legend = 15
fs_tick = 15
fs_title = 18
markersize = 50
yequalsx_line_color = 'xkcd:gray'

def plot(color_dict=None, color_by=None, title=None, cmap=None):
    
    handle_list = []
    if color_dict:
        colors = [color_dict[x] for x in df[color_by]]
        for key in color_dict:
            handle_list.append(Line2D([0],[0], marker='o', markerfacecolor=color_dict[key], markersize=10,
                                  label=key, color='w'))
    else:
        colors = 'b'
    
    fig, axs = plt.subplots(1, 1, figsize=(8,8))
    
    if cmap:
        im = axs.scatter(eff_sq, eff_hx, c=df[color_by], cmap=cmap, s=markersize)
        handle_list.append(Line2D([0],[0], label='Sq Eff = Hx Eff', color=yequalsx_line_color))
        plt.legend(handles=handle_list, fontsize=fs_legend, loc='upper left')
        plt.title(title, fontsize=fs_title)
        divider = make_axes_locatable(axs)
        cax = divider.append_axes("right", size="5%", pad=0.05)
        cbar = plt.colorbar(im, cax=cax)
        cbar.set_label(color_by, fontsize=fs_legend)
        cbar.ax.tick_params(labelsize=fs_tick)
    else:
        axs.scatter(eff_sq, eff_hx, c=colors, s=markersize)
        handle_list.append(Line2D([0],[0], label='Sq Eff = Hx Eff', color=yequalsx_line_color))
        plt.legend(handles=handle_list, fontsize=fs_legend, loc='upper left')
        plt.title(title, fontsize=fs_title)
    
    axs.plot([0,1], [0,1], c=yequalsx_line_color)
    axs.set_aspect('equal')
    axs.set_xticks(np.arange(0,1.1,0.2))
    axs.set_yticks(np.arange(0,1.1,0.2))
    axs.set_xlabel('Square Efficiency', fontsize=fs_tick)
    axs.set_ylabel('Hex Efficiency', fontsize=fs_tick)
    axs.tick_params(axis='x', labelsize=fs_tick)
    axs.tick_params(axis='y', labelsize=fs_tick)
    
    plt.show()

# %%
title = 'Hex Efficiency vs. Square Efficiency'
plot(title=title)

# %%
color_dict = {
    'Early':'xkcd:red',
    'Middle':'xkcd:orange',
    'Middle, Late':'xkcd:green',
    'Late':'xkcd:blue'
}
color_by = 'Period'
title = 'Hex Efficiency vs. Square Efficiency\nColored by Amphora Period'

plot(color_dict=color_dict, color_by=color_by, title=title)

# %%
color_dict = {
    'West':'xkcd:gold',
    'Central':'xkcd:leaf',
    'East':'xkcd:bright blue'
}
color_by = 'Region'
title = 'Hex Efficiency vs. Square Efficiency\nColored by Amphora Region'

plot(color_dict=color_dict, color_by=color_by, title=title)

# %%
color_dict = {
    'Oil':'xkcd:olive',
    'Wine':'xkcd:wine',
    'Fish sauce':'xkcd:salmon',
    'Oil, wine':'xkcd:tan'
}
color_by = 'Content'
title = 'Hex Efficiency vs. Square Efficiency\nColored by Amphora Content'
plot(color_dict=color_dict, color_by=color_by, title=title)

# %%
cmap = 'viridis_r'
color_by = 'Amphora Vol. [L]'
title = 'Hex Efficiency vs. Square Efficiency\nColored by Amphora Volume'

plot(cmap=cmap, color_by=color_by, title=title)

# %% [markdown]
# ## Square packing compared with hexagonal packing
#
# - Currently, there are more jars (6 out of 10) where square packing is more efficient than hexagonal packing.
# - Of the 4 jars where hexagonal packing is more efficient, there are 2 jars where square and hexagonal packing are pretty much equally efficient.

# %%
df[df['Sq. Pack. Eff. (Auto)'] > df['Hex. Pack. Eff. (Auto)']]
# Out:
#                 Status as of 9/9/21 according to J.V.  \
# 1                             Reg sq and reg hex done
# 6   Reg sq and reg hex done, spaced rect and hex done
# 7                             Reg sq and reg hex done
# 8                             Reg sq and reg hex done
# 9                             Reg sq and reg hex done
# 10                            Reg sq and reg hex done
# 11                            Reg sq and reg hex done
# 12                            Reg sq and reg hex done
#
#                  Amphora Type  Period   Region    Content  \
# 1          Africana 2A Grande  Middle  Central       Wine
# 6                  Dressel 20   Early     West        Oil
# 7                  Gauloise 4   Early     West       Wine
# 8                   Kapitan 2  Middle     East       Wine
# 9                Late Roman 1    Late     East  Oil, wine
# 10               Late Roman 2    Late     East  Oil, wine
# 11               Late Roman 3    Late     East       Wine
# 12  Mid-Roman 1 (/Agora M254)  Middle  Central       Wine
#
#    Model Creation (Initials & Date) Model Check 1 (Initials & Date)  \
# 1                    U.P., 7/13/21                     C.W. 7/20/21
# 6                              E.W.                   U.P., 7/18/21
# 7                      C.W. 7.20/21                    J.V. 8/13/21
# 8                     U.P., 7/13/21                    J.V. 8/11/21
# 9                     S.C., 7/13/21                   U.P., 7/15/21
# 10                      C.W. 8/2/21                    J.V. 9/11/21
# 11                     S.C. 7/26/21                    J.V. 8/27/21
# 12                    U.P., 7/13/21                    J.V. 8/13/21
#
#     Model Check 2 (Initials & Date)  Amphora Vol. [L]  Sq. Unit Width [m]  \
# 1                      J.V. 7/24/21         77.900000               0.447
# 6   JV has a question, see comment.         76.151747               0.541
# 7                               NaN         34.908062               0.412
# 8                               NaN         12.629000               0.259
# 9                      C.W. 7/20/21         24.359309               0.313
# 10                              NaN         77.177000               0.539
# 11                              NaN          4.444057               0.181
# 12                              NaN         19.809250               0.328
#
#     Sq. Unit Height [m]  Sq. Unit Volume [m^3]  Sq. Pack. Eff. (Auto)  \
# 1                 1.200               0.239771               0.649787
# 6                 0.840               0.245852               0.619492
# 7                 0.696               0.118142               0.590952
# 8                 0.790               0.052994               0.476620
# 9                 0.813               0.079649               0.611668
# 10                0.819               0.237937               0.648719
# 11                0.438               0.014349               0.619410
# 12                0.554               0.059602               0.664723
#
#     Hex. Unit Side Length [m]  Hex. Unit Height [m]  \
# 1                     0.44700               1.42800
# 6                     0.54000               1.30000
# 7                     0.41200               1.01000
# 8                     0.25900               1.05500
# 9                     0.31300               1.02950
# 10                    0.53809               0.98388
# 11                    0.18100               0.63100
# 12                    0.32800               0.82700
#
#     Hex. Pack. Unit Volume [m^3]  Hex. Pack. Eff. (Auto)
# 1                       0.741302                0.630512
# 6                       0.984879                0.463926
# 7                       0.445418                0.470229
# 8                       0.183867                0.412113
# 9                       0.262040                0.557762
# 10                      0.740123                0.625656
# 11                      0.053708                0.496469
# 12                      0.231156                0.514179

# %%
df[df['Sq. Pack. Eff. (Auto)'] < df['Hex. Pack. Eff. (Auto)']]
# Out:
#                Status as of 9/9/21 according to J.V.        Amphora Type  \
# 0                            Reg sq and reg hex done  Africana 1 Piccolo
# 2                            Reg sq and reg hex done          Almagro 50
# 3                            Reg sq and reg hex done       Almagro 51A-B
# 4  Reg sq and reg hex done, spaced rect and hex done          Cretoise 1
# 5                            Reg sq and reg hex done          Dressel 1A
#
#          Period   Region     Content Model Creation (Initials & Date)  \
# 0        Middle  Central         Oil                    C.W., 7/14/21
# 2  Middle, Late     West  Fish sauce                     U.P. 7/27/21
# 3  Middle, Late     West  Fish sauce                    U.P., 7/13/21
# 4         Early     East        Wine                    U.P., 7/13/21
# 5         Early  Central        Wine                     S.C. 7/28/21
#
#           Model Check 1 (Initials & Date) Model Check 2 (Initials & Date)  \
# 0                            S.C. 7/21/21                    J.V. 7/24/21
# 2                            J.V. 8/11/21                             NaN
# 3                             J.V. 8/2/21                             NaN
# 4                             J.V. 8/2/21                             NaN
# 5  J.V. 8/27/21 (reg sq) 9/8/21 (reg hex)                             NaN
#
#    Amphora Vol. [L]  Sq. Unit Width [m]  Sq. Unit Height [m]  \
# 0         42.500000             0.29552              1.76435
# 2         18.870000             0.21400              1.58000
# 3         16.581294             0.23900              1.03500
# 4         22.775000             0.27600              0.98900
# 5         21.759870             0.28400              1.53200
#
#    Sq. Unit Volume [m^3]  Sq. Pack. Eff. (Auto)  Hex. Unit Side Length [m]  \
# 0               0.154084               0.551646                    0.29666
# 2               0.072358               0.521576                    0.21400
# 3               0.059120               0.560935                    0.23900
# 4               0.075338               0.604608                    0.27600
# 5               0.123565               0.352201                    0.28400
#
#    Hex. Unit Height [m]  Hex. Pack. Unit Volume [m^3]  Hex. Pack. Eff. (Auto)
# 0               1.79343                      0.410067                0.621850
# 2               1.68200                      0.200127                0.565741
# 3               1.18900                      0.176453                0.563820
# 4               1.13800                      0.225223                0.606733
# 5               1.72300                      0.361055                0.361604
